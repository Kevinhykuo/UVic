# %% [markdown]
# # Lab 5

# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib as mp
import matplotlib.pyplot as plt 
import scipy as sci
import skimage as ski
import PIL as pil

from PIL import Image
from scipy.ndimage import gaussian_filter
from skimage import data
from skimage import data, img_as_float
from skimage.morphology import reconstruction
from skimage.segmentation import chan_vese
from scipy import stats
from textwrap import wrap

# %matplotlib inline
# %config InlineBackend.figure_format = 'pdf'

# %%
D0 = pd.read_csv('/Users/kev/Downloads/BCMB 301A Lab Techniques/Lab 5 - Culturing Hybirdoma Cells and Immodetection/Data/ELISA.csv',
                header=0)

SD = plt.imread('/Users/kev/Downloads/BCMB 301A Lab Techniques/Lab 5 - Culturing Hybirdoma Cells and Immodetection/Data/SDS.tiff',)

WB = plt.imread('/Users/kev/Downloads/BCMB 301A Lab Techniques/Lab 5 - Culturing Hybirdoma Cells and Immodetection/Data/WB.tiff')

# %%
D0.T
# Out:
#                              0                     1  \
# Dilution  Mouse mAb alpha-HT 1  Mouse mAb alpha-HT 2
# 1                        0.628                 0.621
# 2                        0.632                 0.574
# 4                        0.575                 0.568
# 8                         0.48                 0.456
# 16                       0.367                 0.373
# 32                       0.264                 0.259
# 64                       0.214                 0.209
# 128                      0.174                 0.171
# 256                      0.154                  0.15
# 512                      0.144                 0.143
# 1024                     0.143                  0.14
# 2048                     0.145                 0.139
#
#                                     2                            3  \
# Dilution  Mouse mAb alpha-HT sample 1  Mouse mAb alpha-HT sample 2
# 1                               0.598                         0.57
# 2                               0.552                        0.538
# 4                               0.458                        0.472
# 8                               0.374                        0.388
# 16                              0.273                        0.271
# 32                              0.207                        0.206
# 64                              0.175                        0.177
# 128                             0.157                        0.155
# 256                             0.145                        0.144
# 512                             0.141                        0.141
# 1024                            0.146                        0.139
# 2048                             0.14                        0.141
#
#                               4                      5                   6  \
# Dilution  Mouse mAb alpha-OTI 1  Mouse mAb alpha-OTI 2  Rat mAb alpha-HT 1
# 1                         0.139                  0.135               0.294
# 2                          0.14                  0.137               0.303
# 4                         0.138                  0.139               0.272
# 8                          0.14                  0.138               0.283
# 16                        0.145                  0.139               0.269
# 32                         0.14                  0.138               0.216
# 64                        0.141                  0.141               0.198
# 128                       0.139                  0.138               0.155
# 256                       0.137                  0.136               0.143
# 512                       0.136                  0.135               0.141
# 1024                      0.139                  0.136               0.139
# 2048                      0.138                  0.136               0.141
#
#                            7
# Dilution  Rat mAb alpha-HT 2
# 1                      0.303
# 2                      0.273
# 4                      0.273
# 8                      0.285
# 16                     0.251
# 32                     0.192
# 64                     0.182
# 128                    0.153
# 256                    0.144
# 512                    0.138
# 1024                   0.139
# 2048                   0.143

# %%
MH = pd.DataFrame(D0.iloc[0:2,:].mean(axis=0))
MH.columns = ['MH']

MS = pd.DataFrame(D0.iloc[2:4,:].mean(axis=0))
MS.columns = ['MS']

MO = pd.DataFrame(D0.iloc[4:6,:].mean(axis=0))
MO.columns = ['MO']

RH = pd.DataFrame(D0.iloc[6:8,:].mean(axis=0))
RH.columns = ['RH']

# %%
DT = pd.concat([MH, MS, MO, RH], sort=False, axis=1)
DT.columns = [r'Mouse mAb $\alpha$-HT (+ Control)', 
              r'Mouse mAb $\alpha$-HT (Sample)', 
              r'Mouse mAb $\alpha$-OTI (- Control)', 
              r'Rat mAb $\alpha$-HT (- Control)']
DT
# Out:
#       Mouse mAb $\alpha$-HT (+ Control)  Mouse mAb $\alpha$-HT (Sample)  \
# 1                                0.6245                          0.5840
# 2                                0.6030                          0.5450
# 4                                0.5715                          0.4650
# 8                                0.4680                          0.3810
# 16                               0.3700                          0.2720
# 32                               0.2615                          0.2065
# 64                               0.2115                          0.1760
# 128                              0.1725                          0.1560
# 256                              0.1520                          0.1445
# 512                              0.1435                          0.1410
# 1024                             0.1415                          0.1425
# 2048                             0.1420                          0.1405
#
#       Mouse mAb $\alpha$-OTI (- Control)  Rat mAb $\alpha$-HT (- Control)
# 1                                 0.1370                           0.2985
# 2                                 0.1385                           0.2880
# 4                                 0.1385                           0.2725
# 8                                 0.1390                           0.2840
# 16                                0.1420                           0.2600
# 32                                0.1390                           0.2040
# 64                                0.1410                           0.1900
# 128                               0.1385                           0.1540
# 256                               0.1365                           0.1435
# 512                               0.1355                           0.1395
# 1024                              0.1375                           0.1390
# 2048                              0.1370                           0.1420

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress([3,4], DT.iloc[3:5,1])
y = DT[r'Mouse mAb $\alpha$-HT (Sample)'].max()/2
x = (y - intercept)/slope

# %% [markdown]
# ## SDS-Page

# %%
fig, ax = plt.subplots(1, 1)
ax.imshow(SD, aspect='equal')
plt.show()
np.shape(SD)
# Out:
# (2973, 2453, 3)

# %% [markdown]
# ## Western Blot

# %%
plt.plot([0, 1], [1, 1])
